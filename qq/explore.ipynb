# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %matplotlib inline

# %%
df = pd.read_csv("data/userFeature.csv")
df.head()
# Out:
#      LBS  age appIdAction appIdInstall  carrier  consumptionAbility       ct  \
# 0  950.0    4         NaN          NaN        1                   2      3 1
# 1  803.0    2         NaN          NaN        1                   1      3 1
# 2  927.0    1         NaN          NaN        3                   1      3 1
# 3  486.0    4         NaN          NaN        3                   1      1 3
# 4  112.0    5         NaN          NaN        3                   2  3 1 4 2
#
#    education  gender  house    ...     \
# 0          7       2    NaN    ...
# 1          2       1    NaN    ...
# 2          5       1    NaN    ...
# 3          7       1    NaN    ...
# 4          6       1    NaN    ...
#
#                                            interest5  \
# 0  52 100 72 131 116 11 71 12 8 113 28 73 6 132 9...
# 1                                                NaN
# 2  77 72 80 116 101 13 1 109 8 50 6 42 76 9 46 36...
# 3  100 80 92 37 116 13 47 4 71 8 50 28 98 115 6 4...
# ...

# %%
df_new = pd.DataFrame()

# %%
df_new['age'] = df['age']
df_new['gender'] = df['gender']  # to one-hot
df_new['education'] = df['education']
df_new['consumptionAbility'] = df['consumptionAbility']
df_new['LBS'] = df["LBS"]  # to one-hot

# %%
for ct_i in [0,1,2,3,4]:
    df_new['ct_%d' % ct_i] = df['ct'].apply(lambda x:int(str(ct_i) in x.split()))

# %%
for os_i in [0,1,2]:
    df_new['os_%d' % os_i] = df['os'].apply(lambda x:int(str(os_i) in x.split()))

# %%
df_new['carrier'] = df['carrier']
df_new['house'] = df['house'].fillna(0).astype('int')

# %%
vector_feature = ['appIdAction','appIdInstall','interest1','interest2','interest3','interest4','interest5','kw1','kw2','kw3','topic1','topic2','topic3']
for column in
# Out:
# LBS                   float64
# age                     int64
# appIdAction            object
# appIdInstall           object
# carrier                 int64
# consumptionAbility      int64
# ct                     object
# education               int64
# gender                  int64
# house                 float64
# interest1              object
# interest2              object
# interest3              object
# interest4              object
# interest5              object
# kw1                    object
# kw2                    object
# kw3                    object
# marriageStatus         object
# os                     object
# topic1                 object
# topic2                 object
# topic3                 object
# uid                     int64
# dtype: object

# %%
for ms_i in {0, 10, 11, 12, 13, 14, 15, 2, 3, 5, 6, 8, 9}:
    df_new['ms_%d' % ms_i] = df['marriageStatus'].fillna("-1").apply(lambda x:int(str(ms_i) in x.split()))

# %%
df_new
# Out:
#           age  gender  education  consumptionAbility    LBS  ct_0  ct_1  ct_2  \
# 0           4       2          7                   2  950.0     0     1     0
# 1           2       1          2                   1  803.0     0     1     0
# 2           1       1          5                   1  927.0     0     1     0
# 3           4       1          7                   1  486.0     0     1     0
# 4           5       1          6                   2  112.0     0     1     1
# 5           1       1          2                   0  589.0     1     0     0
# 6           4       1          7                   1  244.0     0     1     0
# 7           5       1          2                   1  464.0     0     1     0
# 8           5       1          6                   1  585.0     0     1     0
# 9           1       2          7                   1  705.0     0     1     0
# 10          2       1          2                   1  100.0     0     1     0
# ...
